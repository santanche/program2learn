# %%
(define var 2)
var
# Out:
# 2

# %%
(define (f x) (* 2 x))

(f 2)
# Out:
# 4

# %%
(define v (lambda (x) (* 4 x)))

(v 3)
# Out:
# 12

# %%
((lambda (v1 v2) (+ v1 v2)) 1 2)
# Out:
# 3

# %%
(let ([v1 1]
      [v2 2])
  (+ v1 v2))
# Out:
# 3
